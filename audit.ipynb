# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
audit_df = pd.read_excel('audit_et_controle.xlsx')
audit_df.head(2)
# Out:
#          Date de dépôt      Nom                  Prenom  \
# 0  2020-10-19 00:00:00  NITIEMA  Wondpagnande Marceline
# 1  2020-10-19 00:00:00  EVILARO        Grâce Ursula Aye
#
#                         Impétrant Contact  \
# 0  NITIEMA Wondpagnande Marceline     NaN
# 1        EVILARO Grâce Ursula Aye     NaN
#
#                                                Thème             Thématique  \
# 0  Mise en place d'une comptablité générale dans ...  Comptabilité générale
# 1  Audit interne dans la performance finiancère d...          Audit interne
#
#                                Domaine            Filière    Entité Directeur  \
# 0  Comptabilité et gestion financière   Audit et contrôle     ALPHA       NaN
# 1            Audit et contrôle interne  Audit et contrôle  SIDAM SA       NaN
#
#     Date de soutenance   Mentions
# 0  2020-11-11 00:00:00  Très Bien
# 1  2020-11-11 00:00:00       Bien

# %%
audit_df.groupby('Domaine').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Configuration du style
#plt.style.use('seaborn')  # ou 'ggplot' pour un autre style esthétique
plt.figure(figsize=(10, 6))  # Taille du graphique

# Création du diagramme
audit_df.groupby('Domaine').size().sort_values().plot(
    kind='barh',
    color=sns.color_palette('Dark2'),
    edgecolor='black',
    linewidth=0.5
)

# Personnalisation
plt.title('Répartition par domaine en audit et contrôle', pad=20, fontsize=14, fontweight='bold')
plt.xlabel('Nombre', labelpad=10)
plt.ylabel('Domaine', labelpad=10)

# Suppression des bordures inutiles
for spine in ['top', 'right', 'left']:
    plt.gca().spines[spine].set_visible(False)

# Ajout d'une grille discrète
plt.grid(axis='x', linestyle='--', alpha=0.4)

# Ajustement des marges
plt.tight_layout()

# Affichage
plt.show()

# %%
# Configuration du style
#plt.style.use('seaborn')  # ou 'ggplot' pour un autre style esthétique
plt.figure(figsize=(10, 6))  # Taille du graphique

# Création du diagramme
audit_df.groupby('Thématique').size().sort_values().plot(
    kind='barh',
    color=sns.color_palette('Dark2'),
    edgecolor='black',
    linewidth=0.5
)

# Personnalisation
plt.title('Répartition par Thématique en audit et contrôle', pad=20, fontsize=14, fontweight='bold')
plt.xlabel('Nombre', labelpad=10)
plt.ylabel('Thématique', labelpad=10)

# Suppression des bordures inutiles
for spine in ['top', 'right', 'left']:
    plt.gca().spines[spine].set_visible(False)

# Ajout d'une grille discrète
plt.grid(axis='x', linestyle='--', alpha=0.4)

# Ajustement des marges
plt.tight_layout()

# Affichage
plt.show()
