# %%
import pandas as pd

# %% [markdown]
# ### On doit définir le domaine la spécialité et la thématique
#
# Les domaines sont:
# - Economies du développement
# - Audit et Contrôle
# - Banque et assurance

# %% [markdown]
# ### Les thématiques sont:
#
# ### Economie du développement
# -
#
# ### Audit et Contrôle
# - Audit et contrôle interne
# - Audit et contrôle externe
# - Gestion des risques
# - Procédures comptables
# - Certification des comptes
# - Evaluation des immobilisatons
# - Conformité réglementaire
# - Comptabilité et gestion financière
#
# ### Banque et assurance
# - Gestion des risques bancaires
# - Financement des PME
# - Bancassurance
# - Digitalisation des services financiers
# - Satisfaction clientèle
# - Crédit et récouvrement

# %%
df = pd.read_excel('bd1-1.xlsx', sheet_name='Sheet1')
df.head(10)
# Out:
#           Date de dépôt        Nom                       Prenom  \
# 0   2020-10-19 00:00:00    NITIEMA       Wondpagnande Marceline
# 1   2020-10-19 00:00:00    EVILARO             Grâce Ursula Aye
# 2   2020-10-16 00:00:00   WABULASA         Kyalemaninwa Faustin
# 3   2020-10-16 00:00:00     NDIAYE  Fatou Raissa Inny Immaculee
# 4   2020-12-01 00:00:00    BATIONO       Marie Prudence Karidja
# 5   2020-12-02 00:00:00  N'GUESSAN                 Amenan Laura
# 6   2020-12-02 00:00:00     KOUAME           Agoh Princess Xena
# 7   2020-12-02 00:00:00     KOUAME          Kouassi Yves Herman
# 8   2021-01-05 00:00:00      DRABO                    Fatoumata
# 9   2021-01-05 00:00:00      OSSEY       Kopoin Jean Martial. E
#
#                         Impétrant Contact  \
# 0  NITIEMA Wondpagnande Marceline     NaN
# 1        EVILARO Grâce Ursula Aye     NaN
# 2   WABULASA Kyalemaninwa Faustin     NaN
# 3     NDIAYE Fatou Inny Immaculee     NaN
# 4  BATIONO Marie Prudence Karidja     NaN
# ...
