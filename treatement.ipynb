# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_excel('bd1-1.xlsx', sheet_name='Sheet1')
df.tail(5)
# Out:
#            Date de dépôt      Nom                      Prenom  \
# 181  2025-04-15 00:00:00  MOUNDIN  Moumbagna Aboubakar Sidick
# 182  2025-04-15 00:00:00     YABO            Ossondoh Martial
# 183  2025-04-16 00:00:00    MIAKO            Jean Yves Arnold
# 184  2025-04-17 00:00:00   GNAMBA               Grâce Juvenal
# 185  2025-04-17 00:00:00     SENY                 Mariam Leka
#
#                               Impétrant     Contact  \
# 181  MOUNDIN Moumbagna Aboubakar Sidick  0152240877
# 182               YABO Ossondoh Martial         NaN
# 183              MIAKO Jean Yves Arnold  0103926375
# 184                GNAMBA Grâce Juvenal         NaN
# 185                    SENY Mariam Leka  0777918656
#
#                                                  Thème  \
# 181   Stratégie de conquête des clients par AFGBANK CI
# 182  Analyse des risques opérationnels bancaires da...
# 183  Effet de la croissance économique sur les inég...
# 184  Investissements directs étrangers et croissanc...
# 185  Mise en place d'un système de pilotage de la p...
#
#                                             Thématique  \
# 181                             Satisfaction clientèle
# 182                                Gestion des risques
# 183                                Inégalité de Revenu
# 184  Investissement International; Mouvements de Ca...
# 185                 Système de pilotage de performance
#
#                            Domaine                    Filière     Entité  \
# 181         Satisfaction clientèle        Banque et assurance   AFG BANK
# 182  Gestion des risques bancaires        Banque et assurance   AFG BANK
# 183          Bien être et pauvreté  Economie du développement        NaN
# 184        Economie internationale  Economie du développement        NaN
# 185      Audit et contrôle interne          Audit et contrôle  GIH-UEMOA
#
#              Directeur Date de soutenance Mentions
# 181  KONAN Amoin Lucie                NaN      NaN
# 182    N'GUESSAN Simon                NaN      NaN
# 183   ASSOUMOU Giscard                NaN      NaN
# 184           AKA Brou                NaN      NaN
# 185        KONAN Lucie                NaN      NaN

# %%
domaine = df['Domaine'].unique()
domaine
# Out:
# array(['Comptabilité et gestion financière ', 'Audit et contrôle interne',
#        'Conformité réglementaire', 'Gestion des risques',
#        'Audit et contrôle externe', 'Bancassurance',
#        'Financement des entreprises',
#        'Croissance économique et productivité globale',
#        'Crédit et récouvrement', 'Gestion des risques bancaires',
#        'Bien être et pauvreté', 'Management et stratégies commerciales',
#        'Procédure comptable', 'Evaluation des immobilisations',
#        'Satisfaction clientèle', 'Digitalisation des services financiers',
#        'Developpement économique', 'Economie du travail',
#        'Certification des comptes',
#        'Croissance Economique et Productivité Aggregée',
#        'Développement économique', 'Economie agricole',
#        'Economie environnemental', 'Gestion du risque bancaire',
#        'Commerce International', 'Economie publique',
#        'Démographie économique', 'Analyse sectorielle',
#        'Economie industrielle', 'Audit opérationnel', 'Audit et contrôle',
#        'Développement durable', 'Macroéconomie', 'Finance internationale',
#        'Economie internationale'], dtype=object)

# %%
domaine = df['Domaine'].value_counts()
domaine
# Out:
# Domaine
# Audit et contrôle interne                         34
# Gestion des risques bancaires                     20
# Gestion des risques                               12
# Financement des entreprises                       11
# Satisfaction clientèle                            11
# Conformité réglementaire                          10
# Comptabilité et gestion financière                10
# Bancassurance                                     10
# Audit et contrôle externe                          7
# Digitalisation des services financiers             5
# Developpement économique                           5
# Crédit et récouvrement                             4
# Evaluation des immobilisations                     4
# Commerce International                             4
# Economie agricole                                  4
# Procédure comptable                                3
# Economie publique                                  3
# Management et stratégies commerciales              3
# Bien être et pauvreté                              3
# Audit et contrôle                                  3
# Economie environnemental                           3
# Economie du travail                                2
# Développement économique                           2
# Economie internationale                            2
# Croissance économique et productivité globale      1
# Certification des comptes                          1
# Croissance Economique et Productivité Aggregée     1
# Démographie économique                             1
# Gestion du risque bancaire                         1
# Economie industrielle                              1
# Analyse sectorielle                                1
# Audit opérationnel                                 1
# Développement durable                              1
# Macroéconomie                                      1
# Finance internationale                             1
# Name: count, dtype: int64

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Filière').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('Domaine').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
filiere = df['Filière'].unique()
filiere
# Out:
# array(['Audit et contrôle', 'Banque et assurance',
#        'Economie du développement'], dtype=object)

# %%
audit_et_controle = df[df['Filière'] == 'Audit et contrôle'].copy()
audit_et_controle.head(5)
# Out:
#          Date de dépôt       Nom                       Prenom  \
# 0  2020-10-19 00:00:00   NITIEMA       Wondpagnande Marceline
# 1  2020-10-19 00:00:00   EVILARO             Grâce Ursula Aye
# 2  2020-10-16 00:00:00  WABULASA         Kyalemaninwa Faustin
# 3  2020-10-16 00:00:00    NDIAYE  Fatou Raissa Inny Immaculee
# 4  2020-12-01 00:00:00   BATIONO       Marie Prudence Karidja
#
#                         Impétrant Contact  \
# 0  NITIEMA Wondpagnande Marceline     NaN
# 1        EVILARO Grâce Ursula Aye     NaN
# 2   WABULASA Kyalemaninwa Faustin     NaN
# 3     NDIAYE Fatou Inny Immaculee     NaN
# 4  BATIONO Marie Prudence Karidja     NaN
#
#                                                Thème  \
# 0  Mise en place d'une comptablité générale dans ...
# 1  Audit interne dans la performance finiancère d...
# 2  Mise à jour du manuel de procédures de cycle d...
# 3  Evaluation du contrôle interne au niveau du cy...
# 4  La gestion du risque opérationnel de la caisse...
#
#                                   Thématique  \
# 0                      Comptabilité générale
# 1                              Audit interne
# 2  Optimisation des processus de trésorérie
# 3                           Contrôle interne
# 4                        Gestion des risques
#
#                                Domaine            Filière      Entité  \
# 0  Comptabilité et gestion financière   Audit et contrôle       ALPHA
# 1            Audit et contrôle interne  Audit et contrôle    SIDAM SA
# 2             Conformité réglementaire  Audit et contrôle  Caritas CI
# 3            Audit et contrôle interne  Audit et contrôle     epsilon
# 4                  Gestion des risques  Audit et contrôle      AEB-CI
#
#   Directeur   Date de soutenance   Mentions
# 0       NaN  2020-11-11 00:00:00  Très Bien
# 1       NaN  2020-11-11 00:00:00       Bien
# 2       NaN  2020-12-22 00:00:00       Bien
# 3       NaN  2020-12-22 00:00:00  Très Bien
# 4       NaN  2020-12-21 00:00:00       Bien

# %%
audit_et_controle.to_excel('audit_et_controle.xlsx', index=False)

# %%
Banque_et_assurance = df[df['Filière'] == 'Banque et assurance'].copy()
Banque_et_assurance.head(5)
# Out:
#            Date de dépôt     Nom                  Prenom  \
# 7    2020-12-02 00:00:00  KOUAME     Kouassi Yves Herman
# 8    2021-01-05 00:00:00   DRABO               Fatoumata
# 9    2021-01-05 00:00:00   OSSEY  Kopoin Jean Martial. E
# 14   2021-03-31 00:00:00  TRAORE            Hadja Nissia
# 15   2021-03-31 00:00:00   KOFFI    Ahou Marie Madelaine
#
#                      Impétrant Contact  \
# 7    KOUAME Agoh Princess Xena     NaN
# 8              DRAGO Fatoumata     NaN
# 9    OSSEY Kopoin Jean Martial     NaN
# 14         TRAORE Hadja Nissia     NaN
# 15  KOFFI Ahou Marie Madelaine     NaN
#
#                                                 Thème  \
# 7   Analyse de l'impact de l'extension du reseau d...
# 8   Analyse de la politique de vente du produit fi...
# 9   Financement des PME à la SIB analyse des diffi...
# 14  Analyse des facteurs des impayés dans une inst...
# 15  Optimisation du risque de crédit liée à la cli...
#
#                      Thématique                      Domaine  \
# 7   Analyse du réseau des soins                Bancassurance
# 8            Politique de vente     Conformité réglementaire
# 9           Financement des PME  Financement des entreprises
# 14          Gestion des risques       Crédit et récouvrement
# 15          Gestion des risques       Crédit et récouvrement
#
#                 Filière            Entité Directeur     Date de soutenance  \
# 7   Banque et assurance    Nsia Assurance       NaN    2020-12-21 00:00:00
# 8   Banque et assurance        Loyale vie       NaN    2021-05-07 00:00:00
# 9   Banque et assurance               SIB       NaN    2021-05-11 00:00:00
# 14  Banque et assurance     Credit Access       NaN    2021-05-14 00:00:00
# 15  Banque et assurance  Banque populaire       NaN    2021-05-14 00:00:00
#
#      Mentions
# 7        Bien
# 8        Bien
# 9        Bien
# 14  Très Bien
# 15  Très Bien

# %%
Banque_et_assurance.to_excel('Banque_et_assurance.xlsx', index=False)

# %%
Economie_du_developpement = df[df['Filière'] == 'Economie du développement'].copy()
Economie_du_developpement.head(5)
Economie_du_developpement.to_excel('Economie_du_developpement.xlsx', index=False)

# %%
Entité = df['Entité'].unique()
Entité

# %%
# Compter toutes les modalités de la colonne
counts = df['Entité'].value_counts()
counts

# %%
df.to_excel('bd1.xlsx', index=False)

# %%
df['Entité'] = df['Entité'].str.rstrip()

# %%
Entité = df['Entité'].unique()
Entité

# %%
df.to_excel('bd1.xlsx', index=False)

# %%
df['Filière'] = df['Filière'].replace({
    'économie du développement': 'Economie de développement',
    'économie du développement': 'Economie de développement',
})
filière = df['Filière'].unique()
filière

# %%
df['Filière'] = df['Filière'].replace({
    'économie de développement': 'Economie du développement',
})
filière = df['Filière'].unique()
filière

# %%
df['Filière'] = df['Filière'].replace({
    'Economie de développement': 'Economie du développement',
})
filière = df['Filière'].unique()
filière

# %%
df.to_excel('filière.xlsx', index=False)

# %%
df['Filière'] = df['Filière'].str.rstrip()

# %%
filière = df['Filière'].unique()
filière

# %%
df.to_excel('filière.xlsx', index=False)

# %%
df_theme['Filière'] = df_theme['Filière'].replace({'Audit et Controle' and 'Audit et Contrôle': 'Audit et contrôle'})
df_theme.head(10)

# %%
filière = df['Filière'].unique()
filière

# %%
filière = df['Filière'].unique()
filière

# %%
df['Filière'] = df['Filière'].str.rstrip()

# %%
filière = df['Filière'].unique()
filière

# %%
df_theme['Filière'] = df_theme['Filière'].replace({
    'Audit et Controle': 'Audit et contrôle',
    'Audit et Contrôle': 'Audit et contrôle',
    'Audit et Controle': 'Audit et contrôle'
})

# %%
filière = df['Filière'].unique()
filière

# %%
df_theme.to_excel('filière.xlsx', index=False)
