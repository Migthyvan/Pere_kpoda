# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel('bd1-1.xlsx', sheet_name='Sheet1')
df.tail(5)
# Out:
#            Date de dépôt      Nom                      Prenom  \
# 181  2025-04-15 00:00:00  MOUNDIN  Moumbagna Aboubakar Sidick
# 182  2025-04-15 00:00:00     YABO            Ossondoh Martial
# 183  2025-04-16 00:00:00    MIAKO            Jean Yves Arnold
# 184  2025-04-17 00:00:00   GNAMBA               Grâce Juvenal
# 185  2025-04-17 00:00:00     SENY                 Mariam Leka
#
#                               Impétrant     Contact  \
# 181  MOUNDIN Moumbagna Aboubakar Sidick  0152240877
# 182               YABO Ossondoh Martial         NaN
# 183              MIAKO Jean Yves Arnold  0103926375
# 184                GNAMBA Grâce Juvenal         NaN
# 185                    SENY Mariam Leka  0777918656
#
#                                                  Thème  \
# 181   Stratégie de conquête des clients par AFGBANK CI
# 182  Analyse des risques opérationnels bancaires da...
# 183  Effet de la croissance économique sur les inég...
# ...

# %%
df.head(5)
# Out:
#          Date de dépôt       Nom                       Prenom  \
# 0  2020-10-19 00:00:00   NITIEMA       Wondpagnande Marceline
# 1  2020-10-19 00:00:00   EVILARO             Grâce Ursula Aye
# 2  2020-10-16 00:00:00  WABULASA         Kyalemaninwa Faustin
# 3  2020-10-16 00:00:00    NDIAYE  Fatou Raissa Inny Immaculee
# 4  2020-12-01 00:00:00   BATIONO       Marie Prudence Karidja
#
#                         Impétrant Contact  \
# 0  NITIEMA Wondpagnande Marceline     NaN
# 1        EVILARO Grâce Ursula Aye     NaN
# 2   WABULASA Kyalemaninwa Faustin     NaN
# 3     NDIAYE Fatou Inny Immaculee     NaN
# 4  BATIONO Marie Prudence Karidja     NaN
#
#                                                Thème  \
# 0  Mise en place d'une comptablité générale dans ...
# 1  Audit interne dans la performance finiancère d...
# 2  Mise à jour du manuel de procédures de cycle d...
# 3  Evaluation du contrôle interne au niveau du cy...
# 4  La gestion du risque opérationnel de la caisse...
#
# ...

# %%
promo_2020 = pd.read_excel('bd1-1.xlsx', sheet_name='2020')
promo_2020.head(5)
# Out:
#   Date de dépôt       Nom                       Prenom  \
# 0    2020-10-19   NITIEMA       Wondpagnande Marceline
# 1    2020-10-19   EVILARO             Grâce Ursula Aye
# 2    2020-10-16  WABULASA         Kyalemaninwa Faustin
# 3    2020-10-16    NDIAYE  Fatou Raissa Inny Immaculee
# 4    2020-12-01   BATIONO       Marie Prudence Karidja
#
#                         Impétrant  Contact  \
# 0  NITIEMA Wondpagnande Marceline      NaN
# 1        EVILARO Grâce Ursula Aye      NaN
# 2   WABULASA Kyalemaninwa Faustin      NaN
# 3     NDIAYE Fatou Inny Immaculee      NaN
# 4  BATIONO Marie Prudence Karidja      NaN
#
#                                                Thème  \
# 0  Mise en place d'une comptablité générale dans ...
# 1  Audit interne dans la performance finiancère d...
# 2  Mise à jour du manuel de procédures de cycle d...
# 3  Evaluation du contrôle interne au niveau du cy...
# 4  La gestion du risque opérationnel de la caisse...
#
# ...

# %%
nombre_ligne = len(promo_2020)
nombre_ligne
# Out:
# 8

# %%
promo_2021 = pd.read_excel('bd1-1.xlsx', sheet_name='2021')
promo_2021.head(5)
# Out:
#           Date de dépôt     Nom                  Prenom  \
# 0   2021-01-05 00:00:00   DRABO               Fatoumata
# 1   2021-01-05 00:00:00   OSSEY  Kopoin Jean Martial. E
# 2   2021-02-09 00:00:00    KDEA     Esther Marie-Noelle
# 3   2021-03-15 00:00:00  FOFANA      Bala Fatim Georgia
# 4   2021-03-31 00:00:00   KANGA            Ange Leandre
#
#                    Impétrant  Contact  \
# 0            DRAGO Fatoumata      NaN
# 1  OSSEY Kopoin Jean Martial      NaN
# 2   KDEA Esther Marie-Noelle      NaN
# 3  FOFANA Bala Fatim Georgia      NaN
# 4         KANGA Ange Leandre      NaN
#
#                                                Thème  \
# 0  Analyse de la politique de vente du produit fi...
# 1  Financement des PME à la SIB analyse des diffi...
# 2  Effet de la consommation des énergies renouvel...
# 3  Analyse de la chaîne de valeur du manioc dans ...
# 4  Analyse de la gestion de la relation client da...
#
#                        Thématique  \
# ...

# %%
nombre_ligne = len(promo_2021)
nombre_ligne
# Out:
# 50

# %%
promo_2022 = pd.read_excel('bd1-1.xlsx', sheet_name='2022')
nombre_ligne = len(promo_2022)
nombre_ligne
# Out:
# 15

# %%
promo_2023 = pd.read_excel('bd1-1.xlsx', sheet_name='2023')
nombre_ligne = len(promo_2023)
nombre_ligne
# Out:
# 33

# %%
promo_2024 = pd.read_excel('bd1-1.xlsx', sheet_name='2024')
nombre_ligne = len(promo_2024)
nombre_ligne
# Out:
# 52

# %%
promo_20245 = pd.read_excel('bd1-1.xlsx', sheet_name='2025')
nombre_ligne = len(promo_20245)
nombre_ligne
# Out:
# 28
