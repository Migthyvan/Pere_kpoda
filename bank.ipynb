# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bank_df = pd.read_excel("Banque_et_assurance.xlsx")
bank_df.head(2)
# Out:
#           Date de dépôt     Nom               Prenom  \
# 0   2020-12-02 00:00:00  KOUAME  Kouassi Yves Herman
# 1   2021-01-05 00:00:00   DRABO            Fatoumata
#
#                    Impétrant Contact  \
# 0  KOUAME Agoh Princess Xena     NaN
# 1            DRAGO Fatoumata     NaN
#
#                                                Thème  \
# 0  Analyse de l'impact de l'extension du reseau d...
# 1  Analyse de la politique de vente du produit fi...
#
#                     Thématique                   Domaine              Filière  \
# 0  Analyse du réseau des soins             Bancassurance  Banque et assurance
# 1           Politique de vente  Conformité réglementaire  Banque et assurance
#
#            Entité Directeur    Date de soutenance Mentions
# 0  Nsia Assurance       NaN   2020-12-21 00:00:00     Bien
# 1      Loyale vie       NaN   2021-05-07 00:00:00     Bien

# %%
bank_df.groupby('Domaine').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
bank_df.groupby('Domaine').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

plt.title('Répartition par domaine en banque et assurance', pad=20, fontsize=14, fontweight='bold')
plt.xlabel('Nombre de travaux', labelpad=10)
plt.ylabel('domaine', labelpad=10)
# Out:
# Text(0, 0.5, 'domaine')

# %%
bank_df.to_excel('Banque_et_assurance.xlsx', index = False)

# %%
# Configuration du style
#plt.style.use('seaborn')  # ou 'ggplot' pour un autre style esthétique
plt.figure(figsize=(10, 6))  # Taille du graphique

# Création du diagramme
bank_df.groupby('Thématique').size().sort_values().plot(
    kind='barh',
    color=sns.color_palette('Dark2'),
    edgecolor='black',
    linewidth=0.5
)

# Personnalisation
plt.title('Répartition par Thématique en banque et assurance', pad=20, fontsize=14, fontweight='bold')
plt.xlabel('Nombre de travaux', labelpad=10)
plt.ylabel('Thématique', labelpad=10)

# Suppression des bordures inutiles
for spine in ['top', 'right', 'left']:
    plt.gca().spines[spine].set_visible(False)

# Ajout d'une grille discrète
plt.grid(axis='x', linestyle='--', alpha=0.4)

# Ajustement des marges
plt.tight_layout()

# Affichage
plt.show()

# %%
# Calcul des données (identique à votre code)
domain_counts = bank_df.groupby('Domaine').size()

# Création du diagramme circulaire
plt.figure(figsize=(10, 8))
domain_counts.plot(
    kind='pie',
    autopct='%1.1f%%',
    colors=sns.palettes.mpl_palette('Dark2'),  # Même palette de couleurs
    wedgeprops={'linewidth': 1, 'edgecolor': 'white'},  # Contours blancs
    startangle=90
)

# Personnalisation du style
plt.title('Répartition par domaine', pad=20, fontweight='bold')
plt.ylabel('')  # Supprime l'étiquette 'Domaine' par défaut
plt.gca().axis('equal')  # Rend le cercle parfait

# Suppression des axes (comme dans votre code barh)
plt.gca().spines[['top', 'right', 'bottom', 'left']].set_visible(False)

plt.tight_layout()
plt.show()
